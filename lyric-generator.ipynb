# %% [markdown]
# # RAP MACHINE - lyric generator

# %% [markdown]
# ## Preprocessing - reading and preparing lyrics data

# %%
import pandas as pd 
#read data from csv file
data = pd.read_csv('songdata.csv')

artists = set(data['artist'])
#create a set of the 5 rappers to be used...
kanyetext = data.loc[data['artist'] == 'Kanye West','text']
draketext = data.loc[data['artist'] == 'Drake','text']
eminemtext = data.loc[data['artist'] == 'Eminem','text']
migostext = data.loc[data['artist'] == 'Migos', 'text']
lilwaynetext = data.loc[data['artist'] == 'Lil Wayne', 'text']

text = [kanyetext, draketext, eminemtext, migostext, lilwaynetext]
text = pd.concat(text)
print(len(kanyetext))
print(len(text))
# Out:
# 106
# 433

# %%
import string

text = ''.join(text) 
#strips punctuation from string 
text = text.lower().translate(str.maketrans('','', ".!()-\""))
print(len(text))
# Out:
# 1085066

# %% [markdown]
# ## Processing

# %%
#LSTM implementation adapted from https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys


chars = sorted(list(set(text))) #get all unique characters in the text
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars)) #map character to index
indices_char = dict((i, c) for i, c in enumerate(chars)) #map index to character
# Out:
# Using TensorFlow backend.
# total chars: 44

# %% [markdown]
# ### Getting ready to train the model by collecting last bits of data into lists...

# %%
import string

text = [kanyetext, draketext, eminemtext, migostext, lilwaynetext]
songs = []
for artist in text:
    for i in artist:
        songs.append(i.lower().translate(str.maketrans('','', ".!()-\""))) #remove these characters from the text
        
text = songs

# %%
# cut the text in semi-redundant sequences of maxlen characters, split by song

maxlen = 40
step = 3
sentences = []
next_chars = []

#breaks text up like this:     
'''["hello darkness my old friend i've come t", 
    "lo darkness my old friend i've come to t", 
    "darkness my old friend i've come to talk", 
    "kness my old friend i've come to talk wi", 
    "ss my old friend i've come to talk with ", 
    "my old friend i've come to talk with you", 
    "old friend i've come to talk with you ag"] --> sentences, and then puts the next char in next_chars'''

for i in range(len(text)): 
    for j in range(0, len(text[i]) - maxlen, step):
        sentences.append(text[i][j: j + maxlen])
        next_chars.append(text[i][j + maxlen])
print('number of sequences:', len(sentences))
# Out:
# number of sequences: 356060

# %%
print('Vectorization...')

#initialize two arrays, X = (maxlen rows x len(chars) cols) x len(sentences), y = len(sentences x len(chars))
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

#for every sequence, mark the appearance of every char in that sequence and then mark the corresponding next char for that sequence
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# ### Training the model!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars))) 
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)
    random_index = random.randint(0, len(text[start_index]) - maxlen - 1) #another random seed
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index][random_index: random_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 356060/356060 [==============================] - 2422s - loss: 1.7654
#
# ----- diversity: 0.2
# ----- Generating with seed: "don't hit again?
# dog are you fucking k"
# don't hit again?
# dog are you fucking king
# i got the could me
# i got to the don't was don't never mean
# i got the corder the pare
# i got the secen
# i got to the beand the same
# i got the could to the down
# i got the cound
# i got to the count
# i never tell the cramp
# i don't never think i got the ready
# i got a show it
# i got a love the down
# i got the drip in the come
# i can see i got a could the see it
# i got the down
#
# ----- diversity: 0.5
# ----- Generating with seed: "don't hit again?
# dog are you fucking k"
# don't hit again?
# dog are you fucking keep that i was home
# the ama pail the could the gonna get the did a down
# i got a could i don't never can't watch for you
# i don't way you a car see i got the deame
# i got than you don't don't give it to shade
# i can fee a lot gotta be it
# and me
# i got the way don't niggas she can't take it
# the love a comin', don't love me
# i and don't don't only right nigga hand
# and i'm not one money
#
# ----- diversity: 1.0
# ----- Generating with seed: "don't hit again?
# dog are you fucking k"
# don't hit again?
# dog are you fucking know dids'd now my soone and the cronirer dondica,
# gotta wen up
# ain't out, baby tee like watch
# wit to gettin an
#
# gutts gotta zetting one lace, if that na late,
# and i nead me
# play junad thing right niggas gir, the foa poople hpad
# i never
# ake lack that you would tell the prangon, and mept me
# i you's things
# i amesh weure it to umow, ofly tell
# peep so fnencus rought,
# is wrakd a
#
# ----- diversity: 1.2
# ----- Generating with seed: "don't hit again?
# dog are you fucking k"
# don't hit again?
# dog are you fucking knowin just andllit
# and your daysurmed luak groke of, toldeck shng bzy
# can't hadd wit toowolrion
# wit to choine you e toneous, they mull boy it anvadar eavy way his traing,
# sle in haperchin', it
#
# and pacinuce, theol in gsamm', wey my lorats giced i up?
# just money kied
# 3usive for fect more down prourton, i would lot fresssy modir?
# i can stoved her shitnen
# thingny beent ruv is fire
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 356060/356060 [==============================] - 2586s - loss: 1.5325
#
# ----- diversity: 0.2
# ----- Generating with seed: "at you, no ricochet
# that pussy boneles"
# at you, no ricochet
# that pussy boneles
# i don't wanna love the shit
# i got the straight in the been
#
# [chorus:]
#
# [chorus:]
#
# [chorus:]
#
# [chorus:]
#
# [chorus:]
#
# [chorus:]
#
# what you don't let the while you
# i said the show you want to be
# i don't know what i don't get the son
# i don't know what i don't let me
# i don't wanna see it
# i got the start that i don't be money
# i don't be the be the back
# i don'
#
# ----- diversity: 0.5
# ----- Generating with seed: "at you, no ricochet
# that pussy boneles"
# at you, no ricochet
# that pussy boneles are day
#
# [chorus:]
# so we make me fire?
# we don't don't know the street
# i sall while you the money, make you the bitches
#
# the bitches to the sport
# i don't do it the was diding,
# not the some i wast the bitches this
# what i don't breaver where i don't know her
# and the pounds my weezy
# the party right now back with the pronda
# you can see the flay i got the we we know
# when you
#
# ----- diversity: 1.0
# ----- Generating with seed: "at you, no ricochet
# that pussy boneles"
# at you, no ricochet
# that pussy boneles recordion feam igure
# using why i'm nuhh
#
# and indestet dun the get dadget it, i dign
# i ind to like the condories   livin' mash yee,
# take it nigga show hit op
# wolloucitin' ring keep forcory
# do the sing
# me folly real tong, at a bitch that heeed
# love up, yeah, straight a fuckin' new you houdd
# mana hah, yeezy oppe coming like pedcharted, y'all ?
# want the man but i hulled if rease
#
# ----- diversity: 1.2
# ----- Generating with seed: "at you, no ricochet
# that pussy boneles"
# at you, no ricochet
# that pussy boneles youa like showswied ttas
#
# [drt us uh, light, i want on the why
# fuck you in longglas bitches thange puts
# fulled on
# bboot packin' in it to homiet lover : 'bout witha the show,
# the iz'd never get it musing
# grean kindont smreins, tours, my paby, be lying gore
# i still tongatic opla right homer just what do
# jeroan' we rought, i pariiu
# in this can'tal
# drakewas you weezyen tus unle's
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 356060/356060 [==============================] - 2437s - loss: 1.4792
#
# ----- diversity: 0.2
# ----- Generating with seed: "w on a little low arm they want me to st"
# w on a little low arm they want me to stay
# i got a show the back the show the body
# i don't be the show the lade
# i got me to go a showing
# i got the shit i don't be a strong
# i got a boy
# i got a lot the back to go
# i don't say it
# and i got a show me the show
# i got the show me the chance
# the shows the show me be a show
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [
#
# ----- diversity: 0.5
# ----- Generating with seed: "w on a little low arm they want me to st"
# w on a little low arm they want me to start that
# i don't ain't got a lot the put a gonna go
#
# [chorus]
#
# [verse 2:]
# i got to get to love to be on the hot
# the fat you a see the lights
# i see you was better back to go through
# i don't love her showin' like my back a beat is
#
# you know
# and she can say leavin' what you say it
# and i took these nigga she to me
# so i got this bitch as the lights
# oh
#
# [chorus]
#
# [c
#
# ----- diversity: 1.0
# ----- Generating with seed: "w on a little low arm they want me to st"
# w on a little low arm they want me to stacked on eating
# don't see i sheowed leavin' me, know
# you sanse us 'cause bitch like a strest to be pussy
# i just ? stay
# after woulcer and ecathions fame to beeod
# and i'm hadiigs and i got me you know
# her walking up vice
# long bormer thall
# tell it winndo, tell her us get your niggas coldedded kany, karier
# man, i would the way so fall man that hit what like trying to see is to rain
#
# ----- diversity: 1.2
# ----- Generating with seed: "w on a little low arm they want me to st"
# w on a little low arm they want me to starking
# dyown a
# bitch infund, it's my dugh thers custufficlly but i'm itting ez hoe
# havin' alsigeongs, i'm lost till i'm bonn
# i'm zades hes bromet like tleausauh rin from
# real coming mamo, plisten
# dicdo, leave wa goddaw stonesictstife money to stick
#
# feep nitfur juss
# flow e're want howp's proacalatoflli
# girldong ourse makelings,
# elssposun agordoataga, tattoththat's fuln possid c
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 356060/356060 [==============================] - 2421s - loss: 1.4529
#
# ----- diversity: 0.2
# ----- Generating with seed: " me a good
# show me a good
# show me a "
#  me a good
# show me a good
# show me a little of my should admit it
# i said i got the that i can see you
# i got a beast in the fan
#
# you don't get the hood
# i got the shit the street
# she said i know the shit the she start the shit
# i got the stars and the shit the way you say
# i want to chit
# i got the money on the motherfucker
# i got the shot the beat of the bando
# the way you want to cheet a baby
# i swear that i got the
#
# ----- diversity: 0.5
# ----- Generating with seed: " me a good
# show me a good
# show me a "
#  me a good
# show me a good
# show me a mon the other single
# i can't admit to the heart
# i got a motherfucker
# but i can see me in the big see
# that i got the specking my girls that the fucked
# i got a missloots so i got the grown
# i won't stay to the fucking life
# you don't let me hoe got a lie
# i got my colot my mind
#
# i got the that she like a man
# i know i can say so i'm still all of right now
# he got the light, they d
#
# ----- diversity: 1.0
# ----- Generating with seed: " me a good
# show me a good
# show me a "
#  me a good
# show me a good
# show me a pear let youm the lead mes lop itliwheres then cup embadys
# i wait all
#
#
# they kips me sreen mine
# but nigga but i've ain't rap canntige money
# and how alllows, baain, that's like done gifr that's a phatterching
# far ats and hop the swied impitcoover low wow, gurs
# they be jempin like the fuckings off
# i go away
# there's not no syre and there's into, i'm so dees on the dop the white su
#
# ----- diversity: 1.2
# ----- Generating with seed: " me a good
# show me a good
# show me a "
#  me a good
# show me a good
# show me a b paint
# you scaopetes wit easundnmoog money, musa diama g?
# i'm cucking mildg, i came you like weezy in a ooly
# fufl solatle, fucked cooly had this hit us up dat she, i mezs treing it fall?
# me smellull wall as turffout, diak, dem aint
# in thes pussill bigs buo guess yes ogh, long to yoom man
# stan for it fuck it, i moss toskaffy, jurt us i'm lefes all fam ranger up
# lsy len
# until this w
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 356060/356060 [==============================] - 2664s - loss: 1.4353
#
# ----- diversity: 0.2
# ----- Generating with seed: " that's why i would rather show
# you
# "
#  that's why i would rather show
# you
# i got the street
# she said you know they want you the street
# i can't start the best me
# they can't the fuckin' money baby
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [ch
#
# ----- diversity: 0.5
# ----- Generating with seed: " that's why i would rather show
# you
# "
#  that's why i would rather show
# you
# i'm so we gon' think i could in the fine
# she don't be so much and so back
# for the every look me part
# caught i get a pussy clask that i got a long
# what you're a fuckin' talk and shit is
# she go her to the repond
# you got her and me
# i let you to had to get a secord
# and i never had to feel they want to cell with that a minute
# fuckin' tankin' i can stand your fad
# first back on the be
#
# ----- diversity: 1.0
# ----- Generating with seed: " that's why i would rather show
# you
# "
#  that's why i would rather show
# you
# i got the girl, to do too put a bedy freedon
# same pussy if i evir hu, ashurve foremd with a mbits
# a bitchs, when me but you bout the weikin phen
# aly'szon money sick ya mane
# tckin' that now,
# dishonto, fly
# why the face i gim wall
# best to look world my mecal of
# don't want we stear in the gone
# stay actires in god and they cas
# zellin for the alwayne mest
# hit the retra swident and
#
# ----- diversity: 1.2
# ----- Generating with seed: " that's why i would rather show
# you
# "
#  that's why i would rather show
# you
# and cheeptssiban nowhas
# 'hould iinvewn fresh in these ridiop of lifeting
# brearyet, till i just a droor, we don't brew raaic, the orn surfema is the fi'rl
# i collint lit's staus
# she meis why you had a mock damn my map windult, tcking to dainte, o lips
# so i gorahgo lealt holdrer, love mest just crewined
# pock, t nights they shine rap
# fuck me, i'm a coreiy
# as
#
# feen plan homifuck i can
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 356060/356060 [==============================] - 3000s - loss: 1.4215
#
# ----- diversity: 0.2
# ----- Generating with seed: "look
# uh
#
# [verse 2:]
# this lifesty"
# look
# uh
#
# [verse 2:]
# this lifestyle the money from the world
# i got the shit the game
# i got the shit in the way
# i got the way i said i got a bottle
# i got the way to the shit
# i'm on the way
# i'm so i don't want it
# i got the way to my way
# i want me
# i got the bed the bando, i got the shit
# i want to get the bando
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [
#
# ----- diversity: 0.5
# ----- Generating with seed: "look
# uh
#
# [verse 2:]
# this lifesty"
# look
# uh
#
# [verse 2:]
# this lifestyle in the bout to be just wentin'
# and start in the boody on the bound
#
# [chorus]
#
# you pand in the thing we better line
# i'm so attheres for the world the do it
# the ground of the whole too like some her
# i could go what i still askee sit of the bout to be the shit
# i need shine
# and i don't want it
#
# [chorus]
#
#
# ah oh you head
# i'm on the shit
# i'm a stop in my girlfriend so i
#
# ----- diversity: 1.0
# ----- Generating with seed: "look
# uh
#
# [verse 2:]
# this lifesty"
# look
# uh
#
# [verse 2:]
# this lifestyle ass out as a brand nows as eas and bitch
#
#
# keep a getemer, straight, at the skillion
# they ain't run call 'em
# right, right now i'll be had loum of you
# i have it here that too even i'll come at we don't dust like
# the wroty in and yes do it kindy
# shit aint onry, now here in, yolong, new to ya
# gprevia soper like, i'm
#
# lay frierd
# just the surs and i been waned
# turny fom a bed
#
# ----- diversity: 1.2
# ----- Generating with seed: "look
# uh
#
# [verse 2:]
# this lifesty"
# look
# uh
#
# [verse 2:]
# this lifestyand, take him drake nice brand ricks
# mz, texts her good know, ars, if we of a ginalire of clurserm
# tell me ore,
# you come fantie ahheys llabnrascriate ansmy rest boutimual
# just on toe of the girls bloctors ture,
# for not your nabred hil while aw,
# monst thry do play fuckin fuckin insed distor
#
# questendigge think, phan and he'm joggobl
# welable a am
# now we don't with it run i got to p
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 356060/356060 [==============================] - 2780s - loss: 1.4155
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# spokenkilla, dash, hoffa, you funny nig"
#
# spokenkilla, dash, hoffa, you funny niggas
# i see the face of the bitch i ain
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8d64bad2cab3> in <module>()
#      46                 x[0, t, char_indices[char]] = 1.
#      47
# ---> 48             preds = model.predict(x, verbose=0)[0]
#      49             next_index = sample(preds, diversity)
#      50             next_char = indices_char[next_index]
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose)
#     914         if self.model is None:
#     915             self.build()
# --> 916         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     917
#     918     def predict_on_batch(self, x):
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1592         f = self.predict_function
#    1593         return self._predict_loop(f, ins,
# -> 1594                                   batch_size=batch_size, verbose=verbose)
#    1595
#    1596     def train_on_batch(self, x, y,
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose)
#    1216                 ins_batch = _slice_arrays(ins, batch_ids)
#    1217
# -> 1218             batch_outs = f(ins_batch)
#    1219             if not isinstance(batch_outs, list):
#    1220                 batch_outs = [batch_outs]
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2267         updated = session.run(self.outputs + [self.updates_op],
#    2268                               feed_dict=feed_dict,
# -> 2269                               **self.session_kwargs)
#    2270         return updated[:len(self.outputs)]
#    2271
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/rohit/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
