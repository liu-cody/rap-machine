# %% [markdown]
# # RAP MACHINE - lyric generator

# %% [markdown]
# ## Introduction -
#    #### What is this?
#     - The Rap Machine is a Recurrent Neural Network (specifically an LSTM) implemented using the Python libraries spaCy, keras, and numpy. Its purpose is to generate original rap lyrics after being trained on lyrics from a Kaggle dataset. The second part of this project involves using another LSTM to attempt to learn the style of several artists and, given a new song, predict which artist its style most closely resembles.

# %% [markdown]
# ## Preprocessing - reading and preparing lyrics data

# %%
import pandas as pd 
#read data from csv file
data = pd.read_csv('songdata.csv')

artists = set(data['artist'])
#create a set of the 5 rappers to be used...
kanyetext = data.loc[data['artist'] == 'Kanye West','text']
draketext = data.loc[data['artist'] == 'Drake','text']
eminemtext = data.loc[data['artist'] == 'Eminem','text']
migostext = data.loc[data['artist'] == 'Migos', 'text']
lilwaynetext = data.loc[data['artist'] == 'Lil Wayne', 'text']
jcoletext = data.loc[data['artist'] == 'J Cole', 'text']

text = [kanyetext, draketext, eminemtext, migostext, lilwaynetext, jcoletext]
text = pd.concat(text)
print(len(kanyetext))
print(len(text))
# Out:
# 106
# 501

# %%
import string

text = ''.join(text) 
#strips punctuation from string 
text = text.lower().translate(str.maketrans('','', ".!()-\""))
print(len(text))
# Out:
# 1260730

# %% [markdown]
# ## Processing

# %%
#LSTM implementation adapted from https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys


chars = sorted(list(set(text))) #get all unique characters in the text
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars)) #map character to index
indices_char = dict((i, c) for i, c in enumerate(chars)) #map index to character
# Out:
# Using TensorFlow backend.
# total chars: 44

# %% [markdown]
# ### Getting ready to train the model by collecting last bits of data into lists...

# %%
import string

text = [kanyetext, draketext, eminemtext, migostext, lilwaynetext, jcoletext]
songs = []
for artist in text:
    for i in artist:
        songs.append(i.lower().translate(str.maketrans('','', ".!()-\""))) #remove these characters from the text
        
text = songs

# %%
# cut the text in semi-redundant sequences of maxlen characters, split by song

maxlen = 40
step = 3
sentences = []
next_chars = []

#breaks text up like this:     
'''["hello darkness my old friend i've come t", 
    "lo darkness my old friend i've come to t", 
    "darkness my old friend i've come to talk", 
    "kness my old friend i've come to talk wi", 
    "ss my old friend i've come to talk with ", 
    "my old friend i've come to talk with you", 
    "old friend i've come to talk with you ag"] --> sentences, and then puts the next char in next_chars'''

for i in range(len(text)): 
    for j in range(0, len(text[i]) - maxlen, step):
        sentences.append(text[i][j: j + maxlen])
        next_chars.append(text[i][j + maxlen])
print('number of sequences:', len(sentences))
# Out:
# number of sequences: 413734

# %%
print('Vectorization...')

#initialize two arrays, X = (maxlen rows x len(chars) cols) x len(sentences), y = len(sentences x len(chars))
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

#for every sequence, mark the appearance of every char in that sequence and then mark the corresponding next char for that sequence
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# ### Training the model!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars))) 
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)
    random_index = random.randint(0, len(text[start_index]) - maxlen - 1) #another random seed
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index][random_index: random_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 413734/413734 [==============================] - 1020s - loss: 1.7171
#
# ----- diversity: 0.2
# ----- Generating with seed: "first time you seen one, you was eating "
# first time you seen one, you was eating
# i got a beat
# i get to the feeling
# i don't take it
# i got a see
# i got the start
# i got the see in the see
# i don't stead a mind
# i got the start
# i know i'm a started
# i don't know i'm a start
# i'm so i got the see
# i got the tere
# so i see the start
# i get it
# i got the see
# i got the cather
# i got the start
# i got the same
# so i got the same
# i got the same
# i got the see
#
# ----- diversity: 0.5
# ----- Generating with seed: "first time you seen one, you was eating "
# first time you seen one, you was eating
#
# i'm a need like you they don't get to talking to a poper
# got it come
# she need a go man in the bight and i been standin'
# and to be steaming here and you say the rirh
# they don't take it to stand
# i'm right now
# weezy got man
# i got the seets to the me
# i got the stat what i see the same, i be like they got to say burly wee
# they do where i'm like this crack
# they din't be me
# i c
#
# ----- diversity: 1.0
# ----- Generating with seed: "first time you seen one, you was eating "
# first time you seen one, you was eating ejs that just know straight
# and a tifes, two costry but phore
# than is prose nigga got yourgge
# been dastem with yoursed goin'
# sprookin' about hamedry tternaal me like wait eeah, you see ut
# you got a pull me these backed rap fourece
# h
# mean they roag got bary ny looked
# i don't know my newoard of that
# are the make troigine
# world sa to lovern,
# i can told it
# since that,
# and yea
#
# ----- diversity: 1.2
# ----- Generating with seed: "first time you seen one, you was eating "
# first time you seen one, you was eating woope,
# getting'am notine,
# i lovies li?
# ehand take, like ya be cly
# ics'd troha
# moah 'em
# you don't talk amachumbe
# i'm not
# stane, scaboosliest new ni't is mustliacamena borass fince
# you wank out to my t:ally, prip, bull i some prostrcarred, to ? admidnites out
# and i know wwhole you want lime, it wang my dringed
#
# icong city it, now
# ssleek, we,
# shit city, i weat yaua may, poll
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 413734/413734 [==============================] - 966s - loss: 1.5130
#
# ----- diversity: 0.2
# ----- Generating with seed: ", i'll admit it
# watch your motherfucki"
# , i'll admit it
# watch your motherfucking
# i was love it
# i was love your ass
# i was love your girl
# i need a dick
# i was look and i got the time
# i was got a start
# i don't let the beat
# i'm so where i got a lot
# i want to love the shit
# i was love it
# i said it want to get a be
# i was love shit
# i was been the best
# i was love your nigga
# i got a lot the time
# i was me
# i was love your got the streets
# i was be a bi
#
# ----- diversity: 0.5
# ----- Generating with seed: ", i'll admit it
# watch your motherfucki"
# , i'll admit it
# watch your motherfucking the still
# and say my man it in the press
# i ain't supper the pulling ain't not a seem
#
# i see the whole is
# the deat
# now i ain't not to the tark
# and i'm straver
# i make the strip and this probably more
# you ain't not hope your son the money's broking
# that i got the turnstice
# i was like it
# why the still the one to blow
# if they got the trip
# i laid the secks
# you want my wh
#
# ----- diversity: 1.0
# ----- Generating with seed: ", i'll admit it
# watch your motherfucki"
# , i'll admit it
# watch your motherfucking dapp
# i made's do, yeah we need to graw jamme
# bad then we a
# oh instuke cheace whell's and if they only you thilk your
# raw light streets to your,
# that i call your dew i don't get hight
# you actire it
# i can shitty , but i los] where but did to at the goo
# in them
# you ain't begindref
# gate
# and so whole boy
#
# [chorus]
#
# high
#
# [oher c'le hhoodk]
# at? city, i never livef
#
# ----- diversity: 1.2
# ----- Generating with seed: ", i'll admit it
# watch your motherfucki"
# , i'll admit it
# watch your motherfucking,
# i rebot sons, nigga trowr, i'm to me nigga get like then, jee
# liuh for town
# flurf sapes, die they giml readue liunly, that wouble clued fuck it
# whist a] as lackck?
# if you getth no avead, are telllin? dick and i needo to rcat of anyharing, nigga was one aga
# hah, is oothafiludeea low, you true evoey boy oj wholewss bitch in elsyrover
# sfamoss ngga chissedarteck a louga when
# yextom
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 413734/413734 [==============================] - 942s - loss: 1.4687
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# oh oh
# oh
# ohyea ohyea ohyea
# oh o"
#
# oh oh
# oh
# ohyea ohyea ohyea
# oh oh
# i got the world
# i got a man
# i got a lot
# i got a change
# i got the same
# i got the world
# i got a change
#
# [chorus]
#
# [chorus]
#
# [chorus]
# i got a start to see you
# i got a ling
# i ain't got a fuck
# i got a show
# i got a hot like a baby
# and i was and they need you
# i got the boy
# i can tell you would be the world
# and i got it
# i got the shit i got a couple
# i got
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# oh oh
# oh
# ohyea ohyea ohyea
# oh o"
#
# oh oh
# oh
# ohyea ohyea ohyea
# oh oh how they got on the cleatin' my double
# i'm the colded up with a
# i get the field to the good
# i swear to be 'em nigga
# and i still like the shit
# it's see your beat and we don't let the me
# i see that we ain't get the cold
# for you
# i ain't tell you find you
# you ain't got a dick as her some motherfucking
# you can see your thugh
# they could had your alsan
# if you let the beat
# i ha
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# oh oh
# oh
# ohyea ohyea ohyea
# oh o"
#
# oh oh
# oh
# ohyea ohyea ohyea
# oh ol like
# say
# with my way to sume when that's what her
# and stop it pass nonhod
# that we know i'mpame is got her purcent of live
# i'm on my smade putths here
# wanna tell my work
# your perfores histy
# tor is didn't keep it feel these muse how like us frommme tow they been
#
# [chorus]
# nigga, with a di'me is time
# i'm not got 'em like wantin' brounce
# slook, and plud 'em to je leamin' at
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# oh oh
# oh
# ohyea ohyea ohyea
# oh o"
#
# oh oh
# oh
# ohyea ohyea ohyea
# oh oh that?
# and she gra litkers jatch was way on togothin'm
# i playin' a full hiad that's atmera sagg
# hows, about my numble srip na buy wow at me be's dightybuther
# brain the pramil
# it's, boltcu as new wimes
#
# rosodin' my danctange right loye, iboppin so wur my green the hone wad' thexefass sayin tash getticn
# at a chloes would styp, in my yone t
# more tij loveg
# prea, came on youy losim
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 413734/413734 [==============================] - 934s - loss: 1.4440
#
# ----- diversity: 0.2
# ----- Generating with seed: "have a big ass crib and a long yard
# we"
# have a big ass crib and a long yard
# we won't can take the car that i wonder
# i'm the straight and they don't wanna be the beat
# i gotta think i don't know i want to be so they
# i got it to the finger
# i got a don't then i got the face
# i'm a can see it to the shit the shit that i'm the straight
# i'm the finger with my boy, hot cond the straight
# i don't know i don't know i don't know i do
# i don't wanna be my shit i don't wann
#
# ----- diversity: 0.5
# ----- Generating with seed: "have a big ass crib and a long yard
# we"
# have a big ass crib and a long yard
# we can do you should be still she got your careflow
# i'm the finger right now you know it
# put it all of the conce and call me
# i know i then we do it in the closs
# i'm a made the shit the face in the game
# i'm too best me what i say in my way
# than i know i ain't no the cold but i can
# you're thinkin', cause i got my nigga
# how you want a live is for you
# i'm fucking pass the back
# i'm a
#
# ----- diversity: 1.0
# ----- Generating with seed: "have a big ass crib and a long yard
# we"
# have a big ass crib and a long yard
# we want to brand ncie oh, you don't i ain't say
# you never right roll talking
# used to got to do it to, namess not got love cauch off tawks and tide
#
# [ohke? and this though? eje like it spot lange over to singna
# and i go i but your eye
#
# [cold lid we, bable do?
# you tryna again and just ain't fuckin' that i'm untrasiss gires
# i aint man i'mm gon' told through out and camen
# i need no'
#
# ----- diversity: 1.2
# ----- Generating with seed: "have a big ass crib and a long yard
# we"
# have a big ass crib and a long yard
# we hive us
# i'm tryin it talking out problabdrcriton they should hard to this an imman canatusaah dick, sewhere me
# given't beok, let a bammyspook why she tmsch, there, then trupped a wool, al'sa just sorry mause me and hurty
# see ?
# don't wannp win ctarpin', more, vouize, your firees
# you think they gundage like man of time h luckes
# miscalingba poene, seeate a givie ya call one histlitgraue,
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 413734/413734 [==============================] - 949s - loss: 1.4259
#
# ----- diversity: 0.2
# ----- Generating with seed: "nobody to know, his daughter twenty five"
# nobody to know, his daughter twenty five
# i was the back the back the same
# i know i'm the back of the back to the face
# i'm the back the face
# i got the chain in the contraband
# i say i got a little probably not be a bitch
# i'm a mind the life the cold to the face
# i know i was first then i got the past
# i was the chance the back and we can see you
# i was the down
# i was the chance is the bottom
# i was the money
# i got a bl
#
# ----- diversity: 0.5
# ----- Generating with seed: "nobody to know, his daughter twenty five"
# nobody to know, his daughter twenty five of the early
# i don't should ball that botta shorty there would all the ass
# do it feel to cold bitches
# i can see i say and back in it
# you back the words in the dick it
# should come to look
# i'm on the face rool the down
# these granubent stay
# i'm like the body what i ain't got a back
#
# [chorus]
# i'm so million no
# oh baby i ain't never see i put it flow
# so tell me they blow with
#
# ----- diversity: 1.0
# ----- Generating with seed: "nobody to know, his daughter twenty five"
# nobody to know, his daughter twenty five you
# they pussy seati roo, the diamonds
# look in, and chasirr
# then we my ass ose my growls and yechechow
# she was in broke you tryna been all is and
# do ask body fell
# god it's only efold plontl
# pronto
# i'm tired into mage when the's too
# decient and chance percase and
# but when i will, say comes
# look at that, kaid i'm col trarpin' your lifes hands like
# who do get your nigga you l
#
# ----- diversity: 1.2
# ----- Generating with seed: "nobody to know, his daughter twenty five"
# nobody to know, his daughter twenty five id
# i hall manfit it youngviten back, girl is his jeanin'
# connepntt
# on these longing time all my rint
# nigga
# then otch is weft as spotone's rich wisc yladney ciin niggaga, yault?
#
# you dgavods, big al
# sit up, teal room or aint xitpy in the holontagisast lifefol anaroody
# honest sky's sticke intleee of cuip skut styodciw droke my live, i'm just frulk
# i bllaw my heart then you har?
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 413734/413734 [==============================] - 959s - loss: 1.4137
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# but you can miss me with all that,
# "
#
# but you can miss me with all that,
# i want to see it on the trapper
# i seen your mind when i got the shit
# i got the shit the shit the problems
# i said i got the show that i got the thing
# i seen your money so i got the drow the shit
# i said i seen me so hands to the world
#
# [chorus]
#
# [versn
#
# yezy the shot
#
# [chorus]
#
# [chorus]
# i got the shit on the shit and i got the shit
# i got the shit
# i can't stop it to t
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# but you can miss me with all that,
# "
#
# but you can miss me with all that,
# i can't say i got a shit man
# that's what i seen me up
# i can't get a lot of the best like that
# so to see the show your susile you got bast
# and i would never do it up
# you can't fly the bottom
#
# [chorus]
#
# [veroenek]
#
# i got a show her bright in the skittin'
#
# [chorus:]
#
# you can talk the time down
# i got the bad girls and the world
# i mistalling floor that you see you want
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# but you can miss me with all that,
# "
#
# but you can miss me with all that,
# sundered and refriends trip getting skid going
# i'm dong at a nation', you can't putr off in hun a lack
# floor
# and he's sayin' yh
# you got hyloyroing to the foring
# on 'em you'e rap know up but on my time
#
# you aint hout a tho, needed out to holly, i got kight do me
# till the fucking iu had a prob
# watch all thehairod or we feeling
# yeah
# and on your gettingu fin and the million
# now
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# but you can miss me with all that,
# "
#
# but you can miss me with all that,
# lut spo'd a diamonds, maybe from lone in
# i'm a redytib her rumples, hay but and lety
# i'm saying
# five out a puttin' am so wal in his kandors
# turn whan put
# who even o'smits alize is shit hymecidetel i duck, sheere om same yo' atmamay
# prove it don't know the pbacewars
#
# hot ment's
# see, yeezy cplieian clle sund, put her game to pas bitch like louis
# hang i litty, promouth brand now wa
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 413734/413734 [==============================] - 902s - loss: 1.4038
#
# ----- diversity: 0.2
# ----- Generating with seed: " man you know tha basics
# diamonds your"
#  man you know tha basics
# diamonds your back to the way
# and i see it to the way to the bad
# i want to get the way
# yeah yeaha aint the back in the back
# i want to see me
# i want the way to the bitch
# i got the pack
# i was to the hoes with a bitch
# i want to get a bitch
# i want to get a little
# i want to get the bears
# i want to be the back
# i want to be the fuck the back
# i want to get the bears
# i got a lot of my back t
#
# ----- diversity: 0.5
# ----- Generating with seed: " man you know tha basics
# diamonds your"
#  man you know tha basics
# diamonds your with the face
# but it's a starty be seem to be
# i was go for you
# i get my shit in the heart
# i'm the fuck man
# and i ain't go down
#
# a good my contrast, made it on the bust of my can't have her back on my look in the jack
# i see me can i am i got your who the country
# fuck you bought my worstand it
# so yeah i won't never be that on the country
# i ask you love the back me off a chess
#
# ----- diversity: 1.0
# ----- Generating with seed: " man you know tha basics
# diamonds your"
#  man you know tha basics
# diamonds your wad that this hes the witn , ma?
#
# the back't the asssels
# by my last you're can't know
# newa in my diughthous of deed on a key
# i'm soon right eighle
#
# [lalllare brdga and i need with broke goldent chancern, now might around this year
# now what and about my drahaa mama,
# cause trap
# so actine, i'm our free
# my sly but the head worse right j last fove?
# extlin' chating 'bout my shit
#
# ----- diversity: 1.2
# ----- Generating with seed: " man you know tha basics
# diamonds your"
#  man you know tha basics
# diamonds your deead, about a sun nigga nonhmboomu, burnd lean,
# checho guss?
# pick ton't my be an ymu on a sotln for when move refianet bitches nigga
# canic butmin, son out over?
# you know he know who watch these sick?
# yeah parththicer aing eabut
# you'll let it dy that lahine down
# my petthing, already demonopror pistioo
# keep fouver 'te emetihr gue's who too canna never play irtow consie, no wildages
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 413734/413734 [==============================] - 854s - loss: 1.3977
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# got a new chick, booty round like the"
#
# got a new chick, booty round like the chain
# i got the shit i see your thing
# i was to see the motherfucker
# i was to see the chain
# i got the shit i got the chain
#
# [chorus]
#
# [chorus]
#
# [verse 2:]
# i was to the money we was like the chain
# i was to the days
# i'm a show me to cheat
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [hook]
#
# [chorus]
#
# [verse 2:]
#
# [choru
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# got a new chick, booty round like the"
#
# got a new chick, booty round like the weed
# i have to put me
# my life while i stop callin'
# i ain't need me
# through the brain in the know
# she real no
# i take the time
# i can peop to make it to the chain
# the boy do
# i say some to the chain
# like why i see a name
#
# [hook]
# i was the chain, took me
# i want to shit i was the head
# i was to the fame
# i know that young way i do
#
#
# [chorus]
#
# [chorus]
#
# [choru
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# got a new chick, booty round like the"
#
# got a new chick, booty round like the hoiaddrishe works
# got to take, i ever waster
# your could niggas most batker
# oh the vat so
# and yeades, he's wintoors, from i feel
# i givar man slims like the watch over, i go fould leaked chasions
# like the bando, do victen south
# mama fuck a due
# cas even and he ases don't be uhher carder
# hom a
# when i want to phoat i'll tell me no past
# is chbrete like sbiabe bring tha hearter
# an
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# got a new chick, booty round like the"
#
# got a new chick, booty round like they i kno cunned ild venantay,
# gord imofdni kong me everything
# ngga peef we dirk like ska on chance bere]
# bring your closedfuck, big ponion [bratiny go another hood bigfebfit meun and twofrinored
# imma better better be to caugi tackin' bh y
# t'su mear bih
# y lapse that's one good in't begnosiget cike
# doe nota wise peal ima be guy i cashed of deatine
# nothere, rogurslefflobled
# iom inhing
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 413734/413734 [==============================] - 877s - loss: 1.3910
#
# ----- diversity: 0.2
# ----- Generating with seed: "star, lion of the judah
# all my niggas "
# star, lion of the judah
# all my niggas that you got the money
# i got the shit this is i got the things
# i bet your back the whole time i was a baby
# i got my pack
# i'm a be a beat
# i got the things
# i don't think i got the things
# i said i don't want to go
# i don't want the man
# i got the money when i was win so i don't need me
# i don't want the while i don't be me
# i don't want to could be a bitches
# i got the baby while i
#
# ----- diversity: 0.5
# ----- Generating with seed: "star, lion of the judah
# all my niggas "
# star, lion of the judah
# all my niggas with a perfect
# i say some bitch i'm the money more,
# and i'm gettin' from my put of the city
# i'm the best with a beat his year
# i had the can said to the picture now i was who the me
# i got this is i make the damn better
# i got the holece
# while i say hell this shit i stay the way
# i don't need the man some the shit
# the band me
# i'm a trapped it out a little come bitches
# i stay they
#
# ----- diversity: 1.0
# ----- Generating with seed: "star, lion of the judah
# all my niggas "
# star, lion of the judah
# all my niggas sarchy isally her now that things
# broke ?
# when dem and verhs
# cuz it saunce hegrite on my urcad into me
# no no took carm how on that sivents
# i forget magzing gi oton was some
# bleet me, is where?
# and i'm gotdag if you ain't got you
# steag, we might good new up on couldn't smoke to show your obby jeans
# i stated the much what has have a so crass that's so ridin' off
# you and the shit t
#
# ----- diversity: 1.2
# ----- Generating with seed: "star, lion of the judah
# all my niggas "
# star, lion of the judah
# all my niggas would'be ask la unkin
# okey ki, do yeah game home da irlalkah when your real that atime bits from close of ha dag
#
# freak then hair
# bitch, y'all tell yar bitch, roanteg of it
# now you proper right white on freak
# promag, puck, oh heado bodners
# seirched to wilk me house jumy i fuck you side esegria,
# i'm cause if we the arkny teech, till is my sack
# and they plud else inve your ake chro
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 413734/413734 [==============================] - 879s - loss: 1.3872
#
# ----- diversity: 0.2
# ----- Generating with seed: "at already
# and turned to the greatest,"
# at already
# and turned to the greatest, the the coupe
# i know you want to say the close
# i know you say the best shit i got me and the ground
# i know you say the car
# the car shit the best the coupe the same
# i got the same than the things to show you
# i see you the bando
# i know you say the courter in the back
# i said i won't say it all the same than the way to the ground
# i got the shit the bando
# i said i say i know you th
#
# ----- diversity: 0.5
# ----- Generating with seed: "at already
# and turned to the greatest,"
# at already
# and turned to the greatest, and i can tell the low
# we gon' see it been all the lights
# and i see your fame and me to go
# i'm a mama back to make to make the team
# i want me making me
# got a hold it and real the streets
# i know you and shit
# i send the back to me
# don't love you, i don't love you much this when they say so the fall
# and all the fanction
# now she don't know the cest back sout her show
#
# i get th
#
# ----- diversity: 1.0
# ----- Generating with seed: "at already
# and turned to the greatest,"
# at already
# and turned to the greatest, still inside
# i'm like it's fil' 'bout the blacky bout to satter chi on hit you talk with any witry swizped
# you going all the ear
# no, saynees at something i got that bitches in aall and so the club takine
# yea i know i'm butted off radilk middle
# but his clear living boy so a, you should shept fly
# when on it good my jocoleva
# uh he hang murder playin' money, ok with the and made i fars
#
# ----- diversity: 1.2
# ----- Generating with seed: "at already
# and turned to the greatest,"
# at already
# and turned to the greatest, days estrothings,
#
# so now you when how to get to call em door
# seapic nuictryer yea,
# i kill i mob, how ya be no slavedwexfry brack cal iutry?
# lith girl i know your shit j gims with the store: your'
# kill m ya touch work?
# she westhouss that gone treaming able all that, most
#
# church girl hit haped an passstonies a'se smy
# how mon'te picture truat wit your hoes thick
#
# bry it'll
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 413734/413734 [==============================] - 824s - loss: 1.3815
#
# ----- diversity: 0.2
# ----- Generating with seed: "en it ain't
# clinically insane
# brain "
# en it ain't
# clinically insane
# brain i want to get the boy
# i was all the way to the world
# i say what i want to get my friend
# i don't can't still be me
# i got a life in the way the back
# i don't even worry i don't wanna be some
# i was come the way to the way to me
# i want to go
# i got the time i want to see
# the way the boy to me
# i was when i got the streets a shit
# i was the streets the baby
# i want to get the shit
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "en it ain't
# clinically insane
# brain "
# en it ain't
# clinically insane
# brain in the head
# and the baby niggas
# the ballin' a man i said the lights in the piltin' the too
# i fuck it
# you should call me to heavans a little boy
# that she say a nigga
# i got the same than the callin' a nigga
# but i'm the door curn
# we say stuck boy so i feel me
# the same million
# came wonder my piece like they need to gone
# and i heard me i like to hard
# how to be all the booth
# and
#
# ----- diversity: 1.0
# ----- Generating with seed: "en it ain't
# clinically insane
# brain "
# en it ain't
# clinically insane
# brain off right couplis, call me for feel oce
# oscle of getting fret the won, yeah, then i pal bitch so shit so find no[fit amazin, far an youtgry,
# with him wait i'm slist money
# fuck it up was dyo to cust the bances
# so high, rollion, a lot of rip
# if me wasn't bojzy, iwhy fought from glaw
# belcest rides
# just obbaby some, ma mean the hell that hear me
# cemackshing over in the game sha as nigg
#
# ----- diversity: 1.2
# ----- Generating with seed: "en it ain't
# clinically insane
# brain "
# en it ain't
# clinically insane
# brain it' in thinking to your avingry,
# edge it's been't rieping fuve was girl in the worst in, we think i lost , now shouldechpeho too look peep how to gafsised this yout
# araboymon to cartist's, bojy, drop, son of tupe to's yet
# sometime waita phen dare for the hense
# thought a wound accorely bitch? she think gunar, again caught you fly your dourt?
# her will came
# he haded you that work your pos
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 413734/413734 [==============================] - 804s - loss: 1.4014
#
# ----- diversity: 0.2
# ----- Generating with seed: "ever let the streets down
# haven't left"
# ever let the streets down
# haven't left your back to the start a man
# i got my niggas the start
# i got the way i got the world
# the father go to the shit
# i got the shit i got the world bend
# and i got the show you wasn't the same
# the best all
# i wonder what i got my baby
# i got the shit i got the more in the lights
# i got the shit i got the way the colder
# the shit i got my niggas the hood
# i got my niggas wanna be a bitch
#
# ----- diversity: 0.5
# ----- Generating with seed: "ever let the streets down
# haven't left"
# ever let the streets down
# haven't left the shit the fuckin boy
# and i know i got smoke for the rap
# C:\Users\rohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()
# pers
# so you got the all here
# i wonder what the ground
# you know what i get up
# the back, i be with drink
# i'm a little shit and i got my brother
# i got a hoes i go
# i give a shit what i stand that man
# it's a bush
# to the good money like a deep
# i wonder, and i know the way i got my last
# niggas is my action
# the father sta
#
# ----- diversity: 1.0
# ----- Generating with seed: "ever let the streets down
# haven't left"
# ever let the streets down
# haven't left my ass a good new cood your antfles
# don't tell me god the lights, juebst spare
# i got my girl if you just wanna pi'cl poro
# it's tior that asksel buildess wit me hew upss on of,
# all we at tellow yeah than fuck the man
# this besprd, the thang yellokes, time
#
# [verse 2:]
# lur abcindherrs, monommfessed si'm's pussy go hone can guard his
# this what runery scrock oched, classest manymoss
#
# ----- diversity: 1.2
# ----- Generating with seed: "ever let the streets down
# haven't left"
# ever let the streets down
# haven't left these milmion me the childrad
# i'm up knows on you mamy's taking a for at elnales homah
# iha wow me you stopi, we, wayne insid when we raund, ass the shootweres
# raps, screnonegmken, we made a name?
# and cun de own pipes min now
# had summmy wasn like you nover i diases and 'name thought
# wrong rose, spt your kne popper bout more and ye
# even i just aveating virds, but one if i even wanna ne
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 413734/413734 [==============================] - 893s - loss: 1.3896
#
# ----- diversity: 0.2
# ----- Generating with seed: "think that he don't hear me
# hittin' li"
# think that he don't hear me
# hittin' like a started to the car
# i don't wanna be the game and the world
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [chorus]
#
# [hook:]
# i got my money that i got the baby
# i want the shit i don't wanna be like the class
# the coupe the chains and the starkin' the way
# i was the shit they say i got the money
# i was the money man
# i got the shit the carter i got the
#
# ----- diversity: 0.5
# ----- Generating with seed: "think that he don't hear me
# hittin' li"
# think that he don't hear me
# hittin' like a head so one of my
# i can't start on the fame
# i ask you got a hook i really say i be
# i just want her
# i can't ever could get you say i'm sayin momma
# i got the best right now
# i was the prance with ear that you ain't a thing
# you say that i got the deverse that
# they done hove it
# i'm a marrin' name
# i put it
# and the beat a destrooss, you had a shit
#
# [chorus]
#
# i don't wan
#
# ----- diversity: 1.0
# ----- Generating with seed: "think that he don't hear me
# hittin' li"
# think that he don't hear me
# hittin' like it's atm
# like chartep be in the new hey
# life and a arshard of me feel sinkertage me
# and they hustless you thep dawk you sat she gon' get take a dirallay business you be the grou
# rappers tripped the chains ial spoous porting pandes
# know who i can't fuckin me
# i will beatarils what i get me
# rap, let me take me on pop and i'm be
# and too no loscurns gettin four drawn hanler
# fah, do
#
# ----- diversity: 1.2
# ----- Generating with seed: "think that he don't hear me
# hittin' li"
# think that he don't hear me
# hittin' like, guestgas
# terboid time that let d
# wes goe, sorner paclda, lezayed
# codnicaute from noboroc
# yeah, i call rick at hem
# shit snick the wordahmounes callin', chan
# you're movin' these name
# or what ca firdreds inines make on the weet old
# you didy't suiticies, baby, i cinougig all of me for the way on girl yea yacles like a drim
# there's sleepy, and might what
# you'll was fhough, i'm hol
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 413734/413734 [==============================] - 986s - loss: 1.3853
#
# ----- diversity: 0.2
# ----- Generating with seed: "one day, to project runway
# we done hea"
# one day, to project runway
# we done head we gon' the world
# i got the city call me the streets
# i got the like a baby
# i got to have you to be so much
# i got the streets
# i was the more the streets
#
# [chorus]
#
# i don't know you know i got the so the streets
# i got the streets
#
# [chorus]
#
# i got the like a way to be so much
# i got the streets
# i got the streetic
# the more the world to the boy
# i got to be me
# i go
#
# ----- diversity: 0.5
# ----- Generating with seed: "one day, to project runway
# we done hea"
# one day, to project runway
# we done hear the rolling
# it's a back close
# i nigga make you
# what you say a bey
# these niggas could see the time that i get it so she take the light
# you really sendin like a sen
#
# i was here
# who got that since that i tires i wasn sleeped a drath
# hate me all the bottle ever did it
# they only get up i wonder they went the skin
# the rap and get the couple to a better then shit
# 'cause i got a
#
# ----- diversity: 1.0
# ----- Generating with seed: "one day, to project runway
# we done hea"
# one day, to project runway
# we done hear me make it toas
# doing once to ue or that you proin
# cuz i got to i'm ballin congoo boy
# must couple fast bitches arrin'difuled on home
# but you know how do it never walking mess
# mess butbout m fireighthine for my little smllcwast it, water to scherra, thug this i fly meferurers
# the city take an bar, versather shack
#
# barbodd with drughorm away, yeah
# just what they show me
#
# at the h
#
# ----- diversity: 1.2
# ----- Generating with seed: "one day, to project runway
# we done hea"
# one day, to project runway
# we done heat up into nothing
# the earxy,
# cas
# ya
# me i't ven' 'sh' with my bad now
# dreeb, we the lier fuck
# let's you give balter for x, i grab yours on with
# tak keep pump, y'all ain't atiops woul orh?
# 'causee laugh aroching your mine
# about there all oven man only more
# theilf thrulk watd up that's
# she mobotdiy come ininely a neas' down the pimpion
#
# i can scuch thosere, underst of the em
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 413734/413734 [==============================] - 890s - loss: 1.3845
#
# ----- diversity: 0.2
# ----- Generating with seed: " stay, ok
# uh alright, yeah
# born and "
#  stay, ok
# uh alright, yeah
# born and they wanna be so i got the streets
# i got the dressing
# i got the back in the back
# the boy to clet the streets
#
# [chorus]
#
# i don't still be the streets
# i got the chance
# i got the shit i got the money
# i said i was to stop
# i said it don't say i got the same thing
# i said that i got the same thing
# i got the shit what i got the shit
# i don't go to be so i was a change
# i got a
#
# ----- diversity: 0.5
# ----- Generating with seed: " stay, ok
# uh alright, yeah
# born and "
#  stay, ok
# uh alright, yeah
# born and i got the live and they than a grad you still like it
# now you can be like the rump of my fans for my conder da controm clear
# i don't ain't say someone
# so i can come to it to love
# i might stop beat the real that he smile that you know it
# i know i don't need to be a new
# the mall i was a blems
# what i got the star
# tell the way my dime ball
# she told her on the perfect
# hey, hey, hey
#
# ----- diversity: 1.0
# ----- Generating with seed: " stay, ok
# uh alright, yeah
# born and "
#  stay, ok
# uh alright, yeah
# born and you never guess i'm a kids
# yea washed to pocket butter
# heate of the mine the miduent up in the hanned
# and it's got dumbs, nigga, the court on my powers appija, busines til it
# i live that than ye aon the city, your thesil, the rades
# since ain't no here
# yeah, take the starfell not might rolls wasn't in she whise up
#
# orhah, but you clet the chen whena a shorty
# uh hit the crack that'
#
# ----- diversity: 1.2
# ----- Generating with seed: " stay, ok
# uh alright, yeah
# born and "
#  stay, ok
# uh alright, yeah
# born and go like nowurengue though awenck
# i'll stop to break da pettor to hit asksperaning?
# lines man pantiom
# i'm slavers armert
# that money makin' enyyegmer water i'rm
# they wires o, gown
# no furth losh let me tohbe about treally desuice
# i's getting money, though it keap
# always love school a lum uppencersine i don't pad adigas worlds in yo rams but it best
# tell was, i go didn
# when you just
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 413734/413734 [==============================] - 861s - loss: 1.3805
#
# ----- diversity: 0.2
# ----- Generating with seed: "ffset]
# offset
# she was 16 when she ha"
# ffset]
# offset
# she was 16 when she had a man i can tell you she was the money
# i can get the car
# i put the back that i won't be so the car i swear the shit
# i said that you be so the booth heard
# i done we been a bad
# i live the streets bout it
# i was the beat that you ain't no good
# i done we done we was to my baby
# i was the care
# they say i ain't no be feel a fuck with me
# i was talkin' the floor
# and i was done i said
#
# ----- diversity: 0.5
# ----- Generating with seed: "ffset]
# offset
# she was 16 when she ha"
# ffset]
# offset
# she was 16 when she had to hold up in the carbo
# and i can tell you the ammim
# but i got that shit
# i'm a playing that i did the car i got the back
#
# i don't want to do is be
# so i mean i was just so i won't be down
# that's i like that we done with a brain
# could be was a put it
# the streets we would to the three just was drinks
# and i swear it was dough i don't know who we went
# we on the skeepin in the fo
#
# ----- diversity: 1.0
# ----- Generating with seed: "ffset]
# offset
# she was 16 when she ha"
# ffset]
# offset
# she was 16 when she haddakin' dastordo,
# when a smiding i'll knowle need a vion
# what we sam
# hell a kids back bluat, place like lox for already littel pundkine ones
# don't catch it
# ya'll no money, i never won't even know
# girl now why he wanna flah everything did it before
# and here
#
# let me nothing, i'm the roof uffad
# but my name of clyte, my mw and man
# and leave her goin' tired of some jus through are
#
# ----- diversity: 1.2
# ----- Generating with seed: "ffset]
# offset
# she was 16 when she ha"
# ffset]
# offset
# she was 16 when she hada ye give a frow would yah up on time hah man
#
# niggavall went
# basarr, and the amber right, aone that's duws more yuon
# fack niggas like some bath money, trikition idykeh
# still under place litivie sspsoth, always on you,
# let there's ship take you done seft i tripp
# he doing imma bangeniming at clich, bulbing a pilll clenging
# walted gettin' motherfuckin' emstor i damame when she kiltv
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 413734/413734 [==============================] - 881s - loss: 1.3746
#
# ----- diversity: 0.2
# ----- Generating with seed: "e in
#
# no matter what
# you'll never "
# e in
#
# no matter what
# you'll never been a shit to me
# i swear the best friend to the boy
# i don't want to be me
# i don't want to be the face
# i don't wanna be the shit they the more
# i was be the best
# i know i'm a rich
# i was we got the back the chance
# i don't want to see me
# i got a brain
# i don't let the brother
# i was from the back
# i don't want to be the sending
# i got the back to the back
# i swear the world tha
#
# ----- diversity: 0.5
# ----- Generating with seed: "e in
#
# no matter what
# you'll never "
# e in
#
# no matter what
# you'll never get a little mind
# i swear to see me that i don't want to get me
# and they don't tell you
# and be the chick thing this more
#
# [chorus]
#
# [chorus]
#
# i smell i bout me when i don't need to talk to the shit down
# and i'm a bitch i got a little bit you
# the kid what now we have a thing?
#
# [chorus fly drippin' in the money
# one of the good like a hard
# now i'm like a ment the back
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "e in
#
# no matter what
# you'll never "
# e in
#
# no matter what
# you'll never feel they a mifoh?
# y's tell me do you left my timemen's after
# my life this our tomoohh
# yeah
# doune got no hit it, other baby
# but whips bitches for them, nustake
# like head on the susing
# girl you enanastioo, s, married, shit and home ashin saying?
# anotheld im change and sick at can theve girls on
# better tisting then shit atp the futin'
# never love younstow
# dorien mama bling attru
#
# ----- diversity: 1.2
# ----- Generating with seed: "e in
#
# no matter what
# you'll never "
# e in
#
# no matter what
# you'll never love scacedteop weezy world
# my booth clip, your chivends
#
# yea, 'ye whimte of twair, claim, mewhere out mice
# elsel dick when you glow
# rets the once in key
# i'm sure him up
# does rase, moning, j we d
#
# you k, god nana, i reay i'm inthome, dojy,
# conballs chuzze, help his really wor, oh
# i'd playof of ij yedown
# so shit to yo gruber now, oohdell up like this everything
# kidding in
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 413734/413734 [==============================] - 928s - loss: 1.3736
#
# ----- diversity: 0.2
# ----- Generating with seed: "d rolled up
# like a youhaul truck just "
# d rolled up
# like a youhaul truck just start
# i swear i got the state
# i swear i wanna see it
# i swear to stay
# i swear i'm a lot of start
# i want the business
# i don't wanna be some
# i swear i'm a think i want to stay
# i don't wanna be some ass
# i swear i wanna see the fuckin'
# i swear i wanna see the busines
# i swear to stay
# i don't wanna be some to the start
# i don't think i see the start
# i swear i got me
# i was was
#
# ----- diversity: 0.5
# ----- Generating with seed: "d rolled up
# like a youhaul truck just "
# d rolled up
# like a youhaul truck just wanna have her
# i swear i want to do it
# i make you think we cum a feel to sick
# i wit' the motherfucking that
# i knock the strippin'
# i do it too
# i was was the car
# i'll be the song me
# i got me so she ain't no cold day
# whoa whoasse hoy oh
# it's chatch i swear to stay
# i stay the stays to see is a nigga
# but you know the city that i was couldn't always
# whoa whoarood let money
# th
#
# ----- diversity: 1.0
# ----- Generating with seed: "d rolled up
# like a youhaul truck just "
# d rolled up
# like a youhaul truck just bitch, and that did t's where i to probably spect
# still fucking wonla back me
# they told thas
# but i loved my niggas of the guss ain't
# isbects, am of that
#
# so i hate is is jeavth and all is if my nary po older?
# ive
# don't need kids just never write this hot
# check
# you said it too many,
# they knoches, aliinin' now that hopped best
# i swilled and be for rip it man beama f
# infhigh
#
# ----- diversity: 1.2
# ----- Generating with seed: "d rolled up
# like a youhaul truck just "
# d rolled up
# like a youhaul truck just agreation
#   meath, reveronoriot
# you fucking weiyct, dross back
#
# now uh uh is, what you suff me
# i hope is, scrooked up of fckin' deblerie, it this talk, you nee to selva, when fuck he just make no nigga fact
# parsh when you ribver it fug dain?
#
# defest becut
# much up in, so having myself out came and nide
# dype comema bout stay, 'bout aroopen ri'm he's worry up
# my locade, and and snip
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 413734/413734 [==============================] - 914s - loss: 1.3714
#
# ----- diversity: 0.2
# ----- Generating with seed: "ard
# so put ur panties and ur pants by "
# ard
# so put ur panties and ur pants by my life
# i love the star
# i don't want to stay
#
# [chorus]
#
# i don't take the like a man
# she ain't got a line
# i swear i don't still want to stay
# i don't want to should still like a shit
# i love you the same
# i love it to the thing
# i got the way the star
# i got the star
# i don't want to stay
# i love you say the shit is a do
#
# [chorus]
#
# i don't take the street
# i say i'm
#
# ----- diversity: 0.5
# ----- Generating with seed: "ard
# so put ur panties and ur pants by "
# ard
# so put ur panties and ur pants by the all
# weezy world what you could happen to see the best
# i ain't even think i'm an you can go straight
# i should come on the flow
# i got money
# i bett to say the real
# i put the game and now my baby nigga
# i ain't looking ready, i don't trat
# you can do it be songs
# i see the way it was like a time
# so i was fuckin' with her to do it
# and help her consicant
# so they say i make the s
# ----- diversity: 1.0
# ----- Generating with seed: "ard
# so put ur panties and ur pants by "
# ard
# so put ur panties and ur pants by me
# i'm so you fawer stuunt
# reason o,
# but i'm so collestance thit wait, see and that i swe aur tro that some portion
# try through, ooh state
# and i'm a little bap
# straight
# i eary to looking whut you'll, lie lik,
# him cause
# yeah, i'm differty i
#
# i want and has kill him fasted on follo
# bry hard to al of the year that speak
#
# [chorus: jacve with myself
# so they took this ahah
#
# ----- diversity: 1.2
# ----- Generating with seed: "ard
# so put ur panties and ur pants by "
# ard
# so put ur panties and ur pants by my clean it ph
#
# all you know ya hitted if
# and that wiss it ain't em sunkal auman off in chorhblp
# ja
# now you tell wer
# and i gotti sieple dowe layin' niggas tryna beck
# this's the all tyus's i don't hate to you
# now, she got auy wlieh de0, lady, steak to the i hyple hell i do really bamy
# young hard to do it fly mehant'le eymod that's i tell my guricoo
# right dom of tasbaning if unti
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 413734/413734 [==============================] - 895s - loss: 1.3722
#
# ----- diversity: 0.2
# ----- Generating with seed: "n
# dancing out on the lawn
# fancy like"
# n
# dancing out on the lawn
# fancy like the presenter
# i got the stars
# i don't want the stars
# i don't want the stars
# i don't want the streets
# i got the show the streets, the stars
# i was the streets and the stars
# i was the stars
# i don't want the streets
# the stars and the streets and the wind
# i'm so boy the money
# i got my niggas with the wind
# i don't want to see the streets
# i'm a living
# i got the world
# i don'
#
# ----- diversity: 0.5
# ----- Generating with seed: "n
# dancing out on the lawn
# fancy like"
# n
# dancing out on the lawn
# fancy like i'm so don't tell me
# i don't want the things
#
# [chorus]
#
# [pletch
# i see the while i was don't have the couple shit i do to it
# so i'm pausin on the pressh? hey
# it's where i'm so the come man
# i don't tell you thinking follow me
# i'm so could you aint the man
# can i just say you got my face, this is the party
# when you can see a couple won't take your stars
# i don't want the mind
#
# ----- diversity: 1.0
# ----- Generating with seed: "n
# dancing out on the lawn
# fancy like"
# n
# dancing out on the lawn
# fancy like diamonds, she keep up offs
# eass mars in a can't be the
# greatedic trick, aining
#
# the mese spopin' no thugs, feemed my skey
# we bobbivelig for, then, not make me with me
# in the only facie are addictle much fresh with a coorno
#
# i got the chivion em and fucking with the winting got
# you leaves, i lost your nbumion
# decery tly
# our fiellent out me in the tear p shooss
# i'll bir jump
#
# ----- diversity: 1.2
# ----- Generating with seed: "n
# dancing out on the lawn
# fancy like"
# n
# dancing out on the lawn
# fancy like i'm on that fugs already
# or main time, remiblin' a up? like horns conbidewends,
# we arrrying more of list, got so pahty, rich and problem,
# do what i was consures aughy was hur eatha wanns
# whifs,
# yeah og yo nothing, hello, but you put harrrikefice lo' star, drugs and knos
# a soul under pipping with a shorthince well, never sours?
# night the pentian? i'm soughj jukes with e, in myin' eve
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 413734/413734 [==============================] - 870s - loss: 1.3694
#
# ----- diversity: 0.2
# ----- Generating with seed: "yes closed, now
# feeling like my life f"
# yes closed, now
# feeling like my life for the streets
# and i got my girl, i got a little bit a little nigga
# i know the shit to the shit to my shit in the city
# and i would be on the shit
# i swear i got the streets
# i was an a back and the starting
# and i got a lot of man i got the shit
# i feel a lot of my back to the starting
# i don't take it
# i said you can see the time is the money
# i was all the party
# i got the streets
#
# ----- diversity: 0.5
# ----- Generating with seed: "yes closed, now
# feeling like my life f"
# yes closed, now
# feeling like my life for me
# i know you want
# crazy
# the feet that you say hey
# i got my ass on the chest and rex
# i don't wanna be the streets
# the word to the curchest
# and they gone live
# i like to leave to mean traun it down
# she do it
# how the fuck i got my life and back my girl
# i say but you can't be a shit to see it
# and i got my face on the cher
# i'm a party
# she gon' ask you started to do it
# c
#
# ----- diversity: 1.0
# ----- Generating with seed: "yes closed, now
# feeling like my life f"
# yes closed, now
# feeling like my life free
# she
# i'm raincedic fromss
# what it to huster
# i could i loud up
# and inside never as greand, make shirt
# shine viewent take, this even ' don't do in his hoes
# homey down to right nowe
#
# corkards
# you up open playing, here night
# the bottle work right
# it's reaglass the bitting x
#
# away my baby entartie far
# jet's o prissed the dance burn anam her been anngg
# ain't one on
# a
#
# ----- diversity: 1.2
# ----- Generating with seed: "yes closed, now
# feeling like my life f"
# yes closed, now
# feeling like my life flyodeake i'm a la sskim it
# who me?
# they let 'em on somegannla, i let em digry borted like the night now said we time where
#
# thinkin' don't call it buggbiestal
# if y'all was in these sorry to its sayin' a sebls at the mornin tern your rolese admit's it line, nothing
# so grace it was your
# she cal when helpo times i adhived spo make me f in my eyles
# pope, do you k get suck myeei, nigga b
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/1
# 413734/413734 [==============================] - 947s - loss: 1.3732
#
# ----- diversity: 0.2
# ----- Generating with seed: "you
# why has it been so long? where hav"
# you
# why has it been so long? where haven't stay
# i got the car they say i got the man
# i know you stay the senter
# i got the body with the buss
# i know i know i want to see it
# the best i don't think i know it
# i got the face is it
# the car i got the chains
# the fast i got the bando
# i'm so i want to get the way the can't get the car
# i don't wanna be so i'm a street
# i see the close
# i know i'm a sell the way i know you k
#
# ----- diversity: 0.5
# ----- Generating with seed: "you
# why has it been so long? where hav"
# you
# why has it been so long? where have got your arme
# the grogna old
# yeah i was in the car shit
# oh the desers
# you know you see it through it
#
# [chorus]
# i scrazy a plan is not
# but i see the brother all the money, now the streets
#
# [chorus]
#
# [chorus]
# and i don't can't look to see it
#
# contraband
# i stay for you to see you throw me back
# let your came on the first star
# i don't can't be like i want me to be
#
# ----- diversity: 1.0
# ----- Generating with seed: "you
# why has it been so long? where hav"
# you
# why has it been so long? where havens your believe busy
# chilly bitch, fuck your bitch to killin it
# put the big p
# my first lead, believe the virution though
# i made some yore not the famero, now man, you real pain readneine the catch that fun new yoles with
# tired of dice we give you i got your fats swarvala
# whoges was parders the bad song stalts
# try'na dem harve the hood just done you we is she smoking your up
# they g
#
# ----- diversity: 1.2
# ----- Generating with seed: "you
# why has it been so long? where hav"
# you
# why has it been so long? where having the fact's is and me, with to
# from 'fore my smil worst things,
# agholsfolny, and get a smo' we just grinateg single?
# know, help, is you you day
# but it and turned my
# trunesladie formp, fly, yoa say [zho]
# turnin wit here
# i know oh yes
# your got nows but fror your slee
#
#
# your she sep
# groading whar i feel like its as and mass wizz up to dope oneifi
# jeanon at this nigga gu, must s
#
# --------------------------------------------------
# Iteration 23
# Epoch 1/1
# 413734/413734 [==============================] - 985s - loss: 1.3735
#
# ----- diversity: 0.2
# ----- Generating with seed: "er package
# i want you quickly, to plac"
# er package
# i want you quickly, to place
# i'm a beat
# the world of the best na
# i see it to the star back to the streets
# and i got the back in the back
# i am
# i got the star things
# i got the star the car
# i was a beat a fuck i got the chain
# i say we got a minute
# the way i say we could still be a motherfucker
# i got the best niggas with the back in the way
# i got the change that i told you the seen a party
# i see it to
#
# ----- diversity: 0.5
# ----- Generating with seed: "er package
# i want you quickly, to plac"
# er package
# i want you quickly, to place for the head
# i but i'm blow the countin' like i still bitch
# i better don't tra gran
# the beat
# there wanna get to stay the way i still see who i can see you the money
# i got the whole reachen on me
# i want it for my other life is a flow
# i can be for me
# i'm so wonder in my perver
# i get you was only a best nigga
# i got a pussy and i was the shit is
# that's fuck it to me is me
# is
#
# ----- diversity: 1.0
# ----- Generating with seed: "er package
# i want you quickly, to plac"
# er package
# i want you quickly, to place on my umber
# shrothere, so you like hell to go, fuckin' courters
# bragg ain woke spend a nigga yee
# i'm brided the whittors
# cause weshset, i'm bou ance i just gon' make you nights
# this shit to then strepping
# i get the time, are that raggs
# oh, kkitana
# boats picture?
# and shit i caught a presittlest
# wishood manth, drake when a beathrolls you'll singer to me
# har you wildest to loo
#
# ----- diversity: 1.2
# ----- Generating with seed: "er package
# i want you quickly, to plac"
# er package
# i want you quickly, to placeurale, shit gings, i'm me
# shovet i efthou
# kas sne's not not hurt
# i swit tuney re fristin' a fuck in these only
# emotess you're i hucjus's: i was moves, diwns beains mami from wone yo off
# and until my s, who: sue
# to love it ol' clubry
# in tith
#
# around inspliltiers, motherfuckin' cre,
# sjackscition
# i had it that's park to fucl it systires but we diap
# soul tin call'ditery i'll shint
#
# --------------------------------------------------
# Iteration 24
# Epoch 1/1
# 413734/413734 [==============================] - 872s - loss: 1.6488
#
# ----- diversity: 0.2
# ----- Generating with seed: "mie's verdict
# it was worth it
# cause "
# mie's verdict
# it was worth it
# cause the nigga to the who want the when they all
# blate
# the could
# i say the han mey and thes feel
# i can't still be make head ming
# and my back in my hundnthoeg chent and the who was all i can she a finget
# i ain't no tong
# i don't know i wake it baby
# i don't wank the handin the handd a plewner
# i don't know i coul to be the handte the girl
# i get the nee when got to the who wan wanna
# i
#
# ----- diversity: 0.5
# ----- Generating with seed: "mie's verdict
# it was worth it
# cause "
# mie's verdict
# it was worth it
# cause thes genit thot shit
# there want my boufp move no
# you have therin
# that's wind it to break bir around i to
# mustla say the when i than the first play
# telled a mome,
# from seef the never nee when great or you
# thend we get ther buts the niggas and thes a nitges
# i got no
# there fought you shit i do i walk the ding
# fart the build and i loud a bomfet
# and my baby down, it's whatever lone
#
# ----- diversity: 1.0
# ----- Generating with seed: "mie's verdict
# it was worth it
# cause "
# mie's verdict
# it was worth it
# cause to be gonnggng nut of the handtk hiar
# y' gea
# i'm sur i'ms on
# sha
# on my wise i'm soof me
# put so it up at ways swotle
# hougn goeve pant lay
# smalither in all
# ym truck a cugoy're moneyne coorte whecver me down, some in fen me
# flan one lin'ten there  hat got ar me, they talk sourofingoced
# tesite
# tona, because
# you chate totin baby i net ial stop and like togerit
# tohot a comoth' i
#
# ----- diversity: 1.2
# ----- Generating with seed: "mie's verdict
# it was worth it
# cause "
# mie's verdict
# it was worth it
# cause hop not a cince tapep my are ming  saps
# cubd my ioman sbllurny shoot wospy back wits
# they shindin caing ne a i i boneallinu' my dreams havet dy nat eve i may lama  mak my mioh i chapake at down
# thes mis
# specrit i do
# reatt wheshed is leal? it's
# taket yous,
# ymin, say a dopnet coether fly't kym measas asime toy
# lotbjainneaminen'n yo'? wight
# you goittimxdng vi
# mman y, gewlin and syty
#
# --------------------------------------------------
# Iteration 25
# Epoch 1/1
# 413734/413734 [==============================] - 833s - loss: 2.4416
#
# ----- diversity: 0.2
# ----- Generating with seed: " sound ticklish
# 80k large for the herm"
#  sound ticklish
# 80k large for the hermithis shor fhevy in the
#
#
# other nig to takyt
# i than thoo sgot  th
# i thas themk mo
# ba[basksal
# and
#
#
#
# heyo howthez it t what moo]
# i  thin' stoke
# ther bi blat a me   the
# i  the
# there she
# the
# i that ou sweantitce couhg the when tho sted theresh, t that the
# ther
# win thit the
# that the
# the he
#  there
# [chorurg thoullethin' an he  theve the
# i  thit the
# thet the
# thet that the
#
# ----- diversity: 0.5
# ----- Generating with seed: " sound ticklish
# 80k large for the herm"
#  sound ticklish
# 80k large for the hermithoreca
# hoea
# w yhey
# bite the
# youck a
# thighn ther whe t ther
# i think mo
#
# so
# i's a che
# sor  low whas' me,
# e think stend  thasgavetine stet thogot whas in da the
# eme stok to boh
# cionick shin strind no  bea my pe pa
# and
# lje ? ohan'
# i'm a g out my neines
# n   thatin   a gun that courc do y[goin'd y it i thit ther thoune   ther
# ir
# ill
#   and
# iveranu
# d
# herd o thurkfe tha
#
# ----- diversity: 1.0
# ----- Generating with seed: " sound ticklish
# 80k large for the herm"
#  sound ticklish
# 80k large for the hermismat it is n,dono das
# i
# coon
# ] in'mruseale, a
# we for m, lik'tayd gonang y  whoarreshe yh
# brimta
#
# anrein ching we wane onin dytusano mi[batesen t
#
# a no ol yce,' wash wool  rrin' t ca adsecl you bafl
# noa e lekit yewavxeay kcth c th
# shitl
# whaut
# kfrce9n cana
# bin' nop g
# ] ma  cooist
# our
# enom fat newe lit  nighartjus '
# ci hat tois
# andw in'clest feis athe
# dougmwo donxs'l coreon raes
# b
#
# ----- diversity: 1.2
# ----- Generating with seed: " sound ticklish
# 80k large for the herm"
#  sound ticklish
# 80k large for the hermitbab baoral d
# in otkon maaty
# cu's thingate a theatomesa nat hasatinge to snitcar lot l ghex g ame mes
#  yol
# ckr  tloudes xpy, miel t thitin me ai n ther timbe ver wha frow iu
# it rethimcowre ji germe' sooo wh ariler yoo
#  himy dottssuee hate to 'lrete un7, then moyu
# tep youad ma aosg sa thata g patcen lto mr, ic'tearli cooyd g andhhi sl one
# theatoraate m  angh? chowefu jg i'me sphol sldasth
#
# --------------------------------------------------
# Iteration 26
# Epoch 1/1
# 413734/413734 [==============================] - 910s - loss: 3.6833
#
# ----- diversity: 0.2
# ----- Generating with seed: "ou
# i would like to ignite this track w"
# ou
# i would like to ignite this track w
# noest  b
#   th
# in  thyo  thi mo
# no?
# in ou
#  o
# f '  t  down re s
#  s
# io   , l  t s theg t   in
# sjsendha be  ,
#
# we
# [  s ve rd ano' tou be
# i'n nou
#  t  the     f   t  th rou thu bem
# b i'mw
#   thgo thfck  wh    tothe t
# wou y  thg
#  up infh
# no
#
# wotll she be t thi  the
# ou b   th yo i          win
#
# in       thin
# bac    th  i th v
# bid
#   the
#
# han vhjut   t
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ou
# i would like to ignite this track w"
# ou
# i would like to ignite this track w noct m tran  win t
# is fgorc
# tind itu da adts  lik inste
# s  lom sin
# nowhi st heve nay g o se the m al ttana  tf
#  h
# o
# h
# it  al a she so d
# yo n
# dxp  ru
# be ou
# in' at ous ou[ yine
# a
# ig r t e sthay t tot asta hetim' y fe,ch    moy  is ne nveg
# tourn in
# bann a t o ratdj'r
# thonea  r i'm  tost is     aapi  neh     myu un  pay doh ton ?enht we h ca ut rbnat whe  oo 2 yo  i
# doof
#
# ----- diversity: 1.0
# ----- Generating with seed: "ou
# i would like to ignite this track w"
# ou
# i would like to ignite this track wonck a ihu
# we uge a dsq  epin cin  d te om   wanhhvy rawnul  ife ythe6yj feueey, c
# imo cryan mi  bye no audk
# beenda fdrtina iat
# liav iintrmst  l o tohrh
# th
# n walfnin terati nooonae  f5und[rana  swsy  inmagliinde as n as sepe  cu lehcirio
# is d tib on ut   tithat bbsmehe re  yettb
# liv haa t irla nooetan c  stapon inlv
# goen r  thi slthxcyysdooefslaste v theontt
# [rbax
# efubo me   th tit
#
# ----- diversity: 1.2
# ----- Generating with seed: "ou
# i would like to ignite this track w"
# ou
# i would like to ignite this track wy cw dyol  a ch  urorbwefg torr h
# sheuona y re a
# h? righicl7aann w yattbn  meuc,
# bite peo[tre eic,oosoe tol, t'  winhloound ecthk , evl flxa ba
# gog axd  t k eut lid ano'in oaigo
# mao  w tilow gi  mo scti ojroffnge a
# a
# rli' kicsooh tae rr d
# n c v bt l c  tinl mr tk,
# ak a
# lfus wincaun she' ien gon fowe owith, nees wokrg fi2
# sher[rin yhoki f a saanoute fioe se bsiy wayjoy  esi cle gruo reado
#
# --------------------------------------------------
# Iteration 27
# Epoch 1/1
#  49280/413734 [==>...........................] - ETA: 784s - loss: 4.0893
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-db3368d9ac6e> in <module>()
#      27     model.fit(X, y,
#      28               batch_size=128,
# ---> 29               epochs=1)
#      30
#      31     start_index = random.randint(0, len(text) - maxlen - 1)
#
# ~\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1150                 batch_logs['size'] = len(batch_ids)
#    1151                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1152                 outs = f(ins_batch)
#    1153                 if not isinstance(outs, list):
#    1154                     outs = [outs]
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
